# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/sonu/Desktop/PROJECT/FOREST_AGNI/notebook/data/Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI      Classes  Region
# 0  1.3  3.4  0.5  not fire          0
# 1  1.0  3.9  0.4  not fire          0
# 2  0.3  2.7  0.1  not fire          0
# 3  0.0  1.7  0.0  not fire          0
# 4  1.2  3.9  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#drop day month year
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0           0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1           1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2           2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3           3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4           4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
##Encoding
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.tail()
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 238         238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239         239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240         240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241         241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242         242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      Classes  Region
# 238        1       1
# 239        0       1
# 240        0       1
# 241        0       1
# 242        0       1

# %%
##Independent and  dependent features
X = df.drop('FWI',axis=1)
y = df['FWI']

# %%
X.head()
# Out:
#    Unnamed: 0  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  \
# 0           0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0
# 1           1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0
# 2           2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0
# 3           3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0
# 4           4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 12), (61, 12))

# %%
## Feature selection based on correlation
X_train.corr()
# Out:
#              Unnamed: 0  Temperature        RH        Ws      Rain      FFMC  \
# Unnamed: 0     1.000000     0.222788 -0.367511 -0.187296 -0.055222  0.244364
# Temperature    0.222788     1.000000 -0.656095 -0.305977 -0.317512  0.694768
# RH            -0.367511    -0.656095  1.000000  0.225736  0.241656 -0.653023
# Ws            -0.187296    -0.305977  0.225736  1.000000  0.251932 -0.190076
# Rain          -0.055222    -0.317512  0.241656  0.251932  1.000000 -0.545491
# FFMC           0.244364     0.694768 -0.653023 -0.190076 -0.545491  1.000000
# DMC            0.271848     0.498173 -0.414601  0.000379 -0.289754  0.620807
# DC             0.072597     0.390684 -0.236078  0.096576 -0.302341  0.524101
# ISI            0.317535     0.629848 -0.717804 -0.023558 -0.345707  0.750799
# BUI            0.201261     0.473609 -0.362317  0.035633 -0.300964  0.607210
# Classes        0.196463     0.542141 -0.456876 -0.082570 -0.369357  0.781259
# Region         0.867030     0.254549 -0.394665 -0.199969 -0.059022  0.249514
#
#                   DMC        DC       ISI       BUI   Classes    Region
# Unnamed: 0   0.271848  0.072597  0.317535  0.201261  0.196463  0.867030
# Temperature  0.498173  0.390684  0.629848  0.473609  0.542141  0.254549
# RH          -0.414601 -0.236078 -0.717804 -0.362317 -0.456876 -0.394665
# Ws           0.000379  0.096576 -0.023558  0.035633 -0.082570 -0.199969
# Rain        -0.289754 -0.302341 -0.345707 -0.300964 -0.369357 -0.059022
# FFMC         0.620807  0.524101  0.750799  0.607210  0.781259  0.249514
# DMC          1.000000  0.868647  0.685656  0.983175  0.617273  0.212582
# DC           0.868647  1.000000  0.513701  0.942414  0.543581 -0.060838
# ISI          0.685656  0.513701  1.000000  0.643818  0.742977  0.296441
# BUI          0.983175  0.942414  0.643818  1.000000  0.612239  0.114897
# Classes      0.617273  0.543581  0.742977  0.612239  1.000000  0.188837
# Region       0.212582 -0.060838  0.296441  0.114897  0.188837  1.000000

# %%
#Check for multicollinearity
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)

    return col_corr

# %%
#Thershold -- Domain expertise
corr_features = correlation(X_train,0.85)

# %%
## drop features when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# ## Feature scaling or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.3353872 , -0.84284248,  0.78307967, ..., -0.88272888,
#         -0.62963326, -1.10431526],
#        [ 0.29670993, -0.30175842,  0.64950844, ..., -0.86687565,
#         -0.93058524, -1.10431526],
#        [ 1.02936798,  2.13311985, -2.08870172, ...,  0.61540157,
#          2.7271388 ,  0.90553851],
#        ...,
#        [-0.40721642, -1.9250106 ,  0.9166509 , ..., -1.06504105,
#         -1.06948615, -1.10431526],
#        [ 0.842612  ,  0.50986767, -0.21870454, ...,  0.37760309,
#          0.5973248 ,  0.90553851],
#        [-0.26355798, -0.57230045,  0.98343651, ..., -1.01748135,
#         -0.86113478, -1.10431526]], shape=(182, 9))

# %% [markdown]
# ## Box Plots to understand effect of Standard scaler

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title("X_Train After Scaling")
# Out:
# Text(0.5, 1.0, 'X_Train After Scaling')

# %% [markdown]
# ## Linear Regression MOdel

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg = LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5310423080373834
# R2 Score 0.9842013874151916

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.1331797691846894
# R2 Score 0.9492008839717639

# %% [markdown]
# ## Cross Validation Lasso

# %%
from sklearn.linear_model import  LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train_scaled,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.alpha_
# Out:
# np.float64(0.049796533886308926)

# %%
lassocv.mse_path_
# Out:
# array([[54.04680834, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [46.99139504, 59.81506814, 49.29840831, 75.6645852 , 35.31758355],
#        [41.14908917, 53.9178721 , 42.49594889, 68.35708298, 31.76996123],
#        [36.05788169, 48.41773965, 36.66879347, 61.92819453, 28.67296816],
#        [31.62067285, 42.76466229, 31.68391904, 56.26841266, 24.93183295],
#        [27.75285367, 37.81922812, 27.42599138, 51.28216115, 21.56888645],
#        [24.3807738 , 33.49107651, 23.7950306 , 45.25481907, 18.66094162],
#        [21.44052804, 29.70161639, 20.70460191, 39.90418045, 16.14837778],
#        [18.876308  , 26.38208059, 18.07969934, 35.23429953, 13.97821475],
#        [16.63960395, 23.47341883, 15.85530749, 31.15712074, 12.10483403],
#        [14.68819307, 20.92329068, 13.97555108, 27.59649208, 10.48862803],
#        [12.98525144, 18.68636627, 12.39173305, 24.48611006,  9.09521221],
#        [11.49893734, 16.72312788, 11.06186319, 21.7677198 ,  7.89445038],
#        [10.2013182 , 14.9991189 ,  9.94965275, 19.39216316,  6.86106557],
#        [ 9.06814642, 13.48429046,  9.02375611, 17.31505177,  5.9722389 ],
#        [ 8.0783105 , 12.15220147,  8.25686268, 15.49825178,  5.20846991],
#        [ 7.21342796, 10.98048099,  7.62613185, 13.90854714,  4.5528438 ],
#        [ 6.45749132,  9.94890861,  7.11117548, 12.51700172,  3.99069111],
#        [ 5.79649781,  9.04007002,  6.69464754, 11.29840502,  3.50929245],
#        [ 5.21843764,  8.23876281,  6.36161441, 10.23043133,  3.09746419],
#        [ 4.71266457,  7.53171188,  6.09923004,  9.29470762,  2.74599653],
#        [ 4.2699656 ,  6.90732196,  5.89645437,  8.47412971,  2.44641798],
#        [ 3.88231419,  6.35546212,  5.74343167,  7.75415263,  2.19155766],
#        [ 3.54271656,  5.86727817,  5.63280675,  7.1220963 ,  1.97520698],
#        [ 3.24507798,  5.43490383,  5.55722342,  6.56690368,  1.79199187],
#        [ 2.98408648,  5.05183908,  5.51072584,  6.07893135,  1.6372624 ],
#        [ 2.75511169,  4.71201421,  5.48822878,  5.64976711,  1.50699679],
#        [ 2.55407274,  4.41024533,  5.48539678,  5.27207134,  1.39771812],
#        [ 2.37754224,  4.14199391,  5.49854058,  4.93929274,  1.30641528],
#        [ 2.22240106,  3.90328437,  5.49854058,  4.64615961,  1.23051895],
#        [ 2.08597116,  3.69063268,  5.56019917,  4.38761378,  1.16776797],
#        [ 1.9659162 ,  3.50098406,  5.56019917,  4.15939166,  1.11623041],
#        [ 1.86019735,  3.33165877,  5.65456113,  3.95776947,  1.07424081],
#        [ 1.76703503,  3.18030479,  5.65456113,  3.77949324,  1.04036447],
#        [ 1.6848755 ,  3.04481488,  5.76707568,  3.62171864,  1.01336643],
#        [ 1.61236193,  2.92346604,  5.76707568,  3.48195856,  0.99218458],
#        [ 1.54827557,  2.81461081,  5.88796313,  3.3580375 ,  0.97590638],
#        [ 1.49165092,  2.71684484,  5.88796313,  3.24805179,  0.96383716],
#        [ 1.44154595,  2.62893196,  6.01052473,  3.1503334 ,  0.95513053],
#        [ 1.39716889,  2.54978296,  6.01052473,  3.07232371,  0.94929556],
#        [ 1.35782745,  2.47843742,  6.1297553 ,  3.0041222 ,  0.94584218],
#        [ 1.32291594,  2.41404782,  6.1297553 ,  2.94364011,  0.94435089],
#        [ 1.29190414,  2.35586563,  6.24396137,  2.88962691,  0.94446421],
#        [ 1.26432775,  2.30322922,  6.24396137,  2.84193587,  0.94446421],
#        [ 1.23978001,  2.30322922,  6.3508372 ,  2.79951289,  0.94833631],
#        [ 1.21790439,  2.21232932,  6.3508372 ,  2.76173546,  0.94833631],
#        [ 1.21790439,  2.17308232,  6.44949732,  2.72805794,  0.95553666],
#        [ 1.18093653,  2.13740779,  6.44949732,  2.69761451,  0.95553666],
#        [ 1.1653494 ,  2.10494573,  6.53962246,  2.67077799,  0.96484144],
#        [ 1.15139753,  2.10494573,  6.53962246,  2.6467804 ,  0.96484144],
#        [ 1.13889247,  2.04840439,  6.62906842,  2.62528895,  0.98462185],
#        [ 1.12767067,  2.04840439,  6.62906842,  2.60556754,  0.98462185],
#        [ 1.11567029,  1.99833705,  6.72521984,  2.58827109,  1.00579467],
#        [ 1.10207343,  1.99833705,  6.72521984,  2.57275575,  1.00579467],
#        [ 1.10207343,  1.95276334,  6.84813701,  2.55879468,  1.02045866],
#        [ 1.07960179,  1.95276334,  6.84813701,  2.54621674,  1.02045866],
#        [ 1.07960179,  1.91650282,  6.9672937 ,  2.53487123,  1.02851104],
#        [ 1.06227293,  1.91650282,  6.9672937 ,  2.52468436,  1.03374233],
#        [ 1.06227293,  1.86612642,  7.09231837,  2.50710934,  1.03941548],
#        [ 1.04076106,  1.83328109,  7.09231837,  2.47382575,  1.04078252],
#        [ 1.01056758,  1.80390106,  7.23220302,  2.44452617,  1.01688772],
#        [ 1.01056758,  1.77743217,  7.23220302,  2.41924696,  0.99664085],
#        [ 0.95149813,  1.75405167,  7.36150827,  2.39714743,  0.97899225],
#        [ 0.92206792,  1.73314279,  7.36150827,  2.37782263,  0.96353257],
#        [ 0.89588033,  1.71415911,  7.47865217,  2.36091814,  0.95013294],
#        [ 0.87260136,  1.69740983,  7.47865217,  2.34329501,  0.93846067],
#        [ 0.85183234,  1.68237668,  7.58829135,  2.31911511,  0.92828664],
#        [ 0.83338163,  1.66887181,  7.58829135,  2.29743885,  0.92828664],
#        [ 0.81692777,  1.65672498,  7.68576128,  2.2779427 ,  0.9112244 ],
#        [ 0.80223657,  1.64578614,  7.68576128,  2.2779427 ,  0.90497121],
#        [ 0.78910417,  1.64578614,  7.7734453 ,  2.24457327,  0.89906709],
#        [ 0.77735228,  1.62684838,  7.7734453 ,  2.22993193,  0.89393518],
#        [ 0.76682306,  1.61881965,  7.85159272,  2.21703195,  0.89188403],
#        [ 0.75737655,  1.61155102,  7.85159272,  2.20537098,  0.89201809],
#        [ 0.74889827,  1.60496207,  7.92222846,  2.19480615,  0.89249742],
#        [ 0.74124128,  1.59896589,  7.92222846,  2.18522385,  0.89296164],
#        [ 0.73434333,  1.59339892,  7.98389768,  2.17627236,  0.89385894],
#        [ 0.72812583,  1.58845253,  7.98389768,  2.16843485,  0.89465265],
#        [ 0.72253364,  1.58395779,  8.03891207,  2.16156193,  0.89579896],
#        [ 0.71783539,  1.57986267,  8.03891207,  2.15496479,  0.89702655],
#        [ 0.71380568,  1.57648786,  8.08543201,  2.14896119,  0.89807773],
#        [ 0.71023434,  1.57348909,  8.10110027,  2.14372724,  0.89937766],
#        [ 0.70708497,  1.57093767,  8.10110027,  2.13899271,  0.90029887],
#        [ 0.70431931,  1.5683706 ,  8.13517948,  2.13471209,  0.90176629],
#        [ 0.70190487,  1.56643034,  8.14700464,  2.13060202,  0.90278754],
#        [ 0.69982428,  1.56447979,  8.16027789,  2.12681749,  0.9039768 ],
#        [ 0.69798761,  1.56262901,  8.16027789,  2.12323612,  0.90745302],
#        [ 0.69640871,  1.56104667,  8.18621657,  2.12007836,  0.9103375 ],
#        [ 0.69504143,  1.55970512,  8.19559004,  2.11722158,  0.91301251],
#        [ 0.69384759,  1.55841553,  8.20602054,  2.11461277,  0.91554682],
#        [ 0.69277207,  1.55727816,  8.21566286,  2.11212074,  0.91818253],
#        [ 0.69184606,  1.55629157,  8.22492139,  2.10991155,  0.92050923],
#        [ 0.69105153,  1.55534097,  8.23335249,  2.10791975,  0.92286386],
#        [ 0.69035808,  1.5545191 ,  8.24120961,  2.10600816,  0.92516769],
#        [ 0.68975183,  1.55382012,  8.24839166,  2.10429451,  0.92735124],
#        [ 0.6891973 ,  1.55320115,  8.25558351,  2.10276027,  0.92941189],
#        [ 0.68871533,  1.55258642,  8.26208979,  2.10135606,  0.93118534],
#        [ 0.68830962,  1.55204419,  8.26810318,  2.10000223,  0.93293486],
#        [ 0.68795703,  1.55159188,  8.27338094,  2.09876374,  0.93466187],
#        [ 0.68763122,  1.55119744,  8.27893884,  2.09766351,  0.93630076]])

# %%
y_pred = lassocv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
# Out:
# Mean absolute error 0.6067537747099544
# R2 score 0.9816076640046453

# %% [markdown]
# ## Ridge regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5523063707254479
# R2 Score 0.983676555604412

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,y_train)
y_pred=ridgecv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.5523063707254479
# R2 Score 0.983676555604412

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': False}

# %% [markdown]
# ## Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.8822336088419482
# R2 Score 0.8753464015504889

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv=ElasticNetCV(cv=5)
elasticcv.fit(X_train_scaled,y_train)
y_pred=elasticcv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.6525416416304304
# R2 Score 0.9805069854347187

# %%
elasticcv.alphas_
# Out:
# array([14.11706004, 13.16561744, 12.27829889, 11.45078264, 10.67903821,
#         9.95930678,  9.28808283,  8.66209714,  8.07830078,  7.53385034,
#         7.02609405,  6.55255882,  6.11093829,  5.6990815 ,  5.31498248,
#         4.95677045,  4.62270071,  4.31114616,  4.02058933,  3.74961507,
#         3.49690356,  3.26122397,  3.04142839,  2.83644629,  2.64527931,
#         2.46699633,  2.30072904,  2.1456676 ,  2.00105679,  1.86619226,
#         1.74041714,  1.62311885,  1.51372607,  1.411706  ,  1.31656174,
#         1.22782989,  1.14507826,  1.06790382,  0.99593068,  0.92880828,
#         0.86620971,  0.80783008,  0.75338503,  0.7026094 ,  0.65525588,
#         0.61109383,  0.56990815,  0.53149825,  0.49567705,  0.46227007,
#         0.43111462,  0.40205893,  0.37496151,  0.34969036,  0.3261224 ,
#         0.30414284,  0.28364463,  0.26452793,  0.24669963,  0.2300729 ,
#         0.21456676,  0.20010568,  0.18661923,  0.17404171,  0.16231189,
#         0.15137261,  0.1411706 ,  0.13165617,  0.12278299,  0.11450783,
#         0.10679038,  0.09959307,  0.09288083,  0.08662097,  0.08078301,
#         0.0753385 ,  0.07026094,  0.06552559,  0.06110938,  0.05699082,
#         0.05314982,  0.0495677 ,  0.04622701,  0.04311146,  0.04020589,
#         0.03749615,  0.03496904,  0.03261224,  0.03041428,  0.02836446,
#         0.02645279,  0.02466996,  0.02300729,  0.02145668,  0.02001057,
#         0.01866192,  0.01740417,  0.01623119,  0.01513726,  0.01411706])

# %%
import pickle
pickle.dump(scaler,open("scaler.pkl",'wb'))
pickle.dump(ridge,open("ridge.pkl",'wb'))
